# %%
# !pip install requests
# !pip install bs4
# Out:
# Requirement already satisfied: requests in c:\users\siddhant ghosh\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\siddhant ghosh\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\siddhant ghosh\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\siddhant ghosh\anaconda3\lib\site-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\siddhant ghosh\anaconda3\lib\site-packages (from requests) (2023.7.22)
# Collecting bs4
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in c:\users\siddhant ghosh\anaconda3\lib\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\siddhant ghosh\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.4)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\siddhant ghosh\anaconda3\lib\site-packages (4.9.3)

# %%
from bs4 import BeautifulSoup
import requests

# %%
website = 'https://subslikescript.com/series/Breaking_Bad-903747'
result = requests.get(website)
content= result.text
soup = BeautifulSoup(content, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-120598793-1">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-120598793-1');
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    Breaking Bad Episodes' Transcripts  | Subs like Script
#   </title>
#   <meta content="All available episodes' scripts of Tv Show Breaking Bad " name="description"/>
#   <meta content="transcript, episode, series, tv show, television, subtitles, scripts, film, video, media, subs, srt " name="keywords"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <link as="style" href="https://subslikescript.com/build/assets/app-e41e6ced.css" rel="preload"/>
#   <link href="https://subslikescript.com/build/assets/app-e41e6ced.css" rel="stylesheet"/>
#   <script async="" data-ad-client="ca-pub-6250492176235895" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#  </head>
#  <body>
#   <div class="page-wrapper">
#    <header>
#     <div id="logo">
#      <a href="/" title="Subs like Script - all Movies and TV Shows Transcripts">
#       <span>
#        SUBSLIKESCRIPT
#       </span>
#      </a>
#     </div>
#     <nav>
#      <a href="/movies" target="_self" title="All movies transcripts">
#       Movies
#      </a>
#      <a href="/series" target="_self" title="All Tv Shows transcripts">
#       TV Shows
#      </a>
#     </nav>
#    </header>
#    <div class="main-wrapper">
#     <main class="mainpage">
#      <nav>
#       <ul class="breadcrumb">
#        <li>
#         <a href="/">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="/series">
#          Tv shows
#         </a>
#        </li>
#        <li>
#         Breaking Bad
#        </li>
#       </ul>
#      </nav>
#      <nav>
#       <form action="/search" class="searchzone" method="get" name="search">
#        <input class="searchbox" name="q" type="text"/>
#        <button class="searchbutton">
#         Search
#        </button>
#       </form>
#      </nav>
#      <article class="main-article">
#       <h1>
#        Breaking Bad (2008–2013) - episodes with scripts
#       </h1>
#       <p class="plot">
#        When chemistry teacher Walter White is diagnosed with Stage III cancer and given only two years to live, he decides he has nothing to lose. He lives with his teenage son, who has cerebral palsy, and his wife, in New Mexico. Determined to ensure that his family will have a secure future, Walt embarks on a career of drugs and crime. He proves to be remarkably proficient in this new world as he begins manufacturing and selling methamphetamine with one of his former students. The series tracks the impacts of a fatal diagnosis on a regular, hard working man, and explores how a fatal diagnosis affects his morality and transforms him into a major player of the drug trade.
#       </p>
#       <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#       </script>
#       <!-- subslikescript horizontal links top -->
#       <ins class="adsbygoogle" data-ad-client="ca-pub-6250492176235895" data-ad-format="link" data-ad-slot="3068516580" data-full-width-responsive="true" style="display:block">
#       </ins>
#       <script>
#        (adsbygoogle = window.adsbygoogle || []).push({});
#       </script>
#       <div class="series_seasons">
#        <div class="season">
#         <h4>
#          Season 1
#         </h4>
#         <ul>
#          <li>
#           1.
#           <a href="/series/Breaking_Bad-903747/season-1/episode-1-Pilot" title='Transcript of episode 1 "Pilot"'>
#            Pilot
#           </a>
#          </li>
#          <li>
#           2.
#           <a bag...="" href="/series/Breaking_Bad-903747/season-1/episode-2-Cats_in_the_Bag" in="" s="" the="" title='Transcript of episode 2 "Cat'>
#            Cat's in the Bag...
#           </a>
#          </li>
#          <li>
#           3.
#           <a href="/series/Breaking_Bad-903747/season-1/episode-3-And_the_Bags_in_the_River" in="" river="" s="" the="" title='Transcript of episode 3 "...And the Bag'>
#            ...And the Bag's in the River
#           </a>
#          </li>
#          <li>
#           4.
#           <a href="/series/Breaking_Bad-903747/season-1/episode-4-Cancer_Man" title='Transcript of episode 4 "Cancer Man"'>
#            Cancer Man
#           </a>
#          </li>
#          <li>
#           5.
#           <a href="/series/Breaking_Bad-903747/season-1/episode-5-Gray_Matter" title='Transcript of episode 5 "Gray Matter"'>
#            Gray Matter
#           </a>
#          </li>
#          <li>
#           6.
#           <a href="/series/Breaking_Bad-903747/season-1/episode-6-Crazy_Handful_of_Nothin" title='Transcript of episode 6 "Crazy Handful of Nothin'>
#            Crazy Handful of Nothin'
#           </a>
#          </li>
#          <li>
#           7.
#           <a href="/series/Breaking_Bad-903747/season-1/episode-7-A_No-Rough-Stuff-Type_Deal" title='Transcript of episode 7 "A No-Rough-Stuff-Type Deal"'>
#            A No-Rough-Stuff-Type Deal
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="season">
#         <h4>
#          Season 2
#         </h4>
#         <ul>
#          <li>
#           1.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-1-Seven_Thirty-Seven" title='Transcript of episode 1 "Seven Thirty-Seven"'>
#            Seven Thirty-Seven
#           </a>
#          </li>
#          <li>
#           2.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-2-Grilled" title='Transcript of episode 2 "Grilled"'>
#            Grilled
#           </a>
#          </li>
#          <li>
#           3.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-3-Bit_by_a_Dead_Bee" title='Transcript of episode 3 "Bit by a Dead Bee"'>
#            Bit by a Dead Bee
#           </a>
#          </li>
#          <li>
#           4.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-4-Down" title='Transcript of episode 4 "Down"'>
#            Down
#           </a>
#          </li>
#          <li>
#           5.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-5-Breakage" title='Transcript of episode 5 "Breakage"'>
#            Breakage
#           </a>
#          </li>
#          <li>
#           6.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-6-Peekaboo" title='Transcript of episode 6 "Peekaboo"'>
#            Peekaboo
#           </a>
#          </li>
#          <li>
#           7.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-7-Negro_Y_Azul" title='Transcript of episode 7 "Negro Y Azul"'>
#            Negro Y Azul
#           </a>
#          </li>
#          <li>
#           8.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-8-Better_Call_Saul" title='Transcript of episode 8 "Better Call Saul"'>
#            Better Call Saul
#           </a>
#          </li>
#          <li>
#           9.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-9-4_Days_Out" title='Transcript of episode 9 "4 Days Out"'>
#            4 Days Out
#           </a>
#          </li>
#          <li>
#           10.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-10-Over" title='Transcript of episode 10 "Over"'>
#            Over
#           </a>
#          </li>
#          <li>
#           11.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-11-Mandala" title='Transcript of episode 11 "Mandala"'>
#            Mandala
#           </a>
#          </li>
#          <li>
#           12.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-12-Phoenix" title='Transcript of episode 12 "Phoenix"'>
#            Phoenix
#           </a>
#          </li>
#          <li>
#           13.
#           <a href="/series/Breaking_Bad-903747/season-2/episode-13-ABQ" title='Transcript of episode 13 "ABQ"'>
#            ABQ
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="season">
#         <h4>
#          Season 3
#         </h4>
#         <ul>
#          <li>
#           1.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-1-No_Ms" title='Transcript of episode 1 "No Más"'>
#            No Más
#           </a>
#          </li>
#          <li>
#           2.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-2-Caballo_sin_Nombre" title='Transcript of episode 2 "Caballo sin Nombre"'>
#            Caballo sin Nombre
#           </a>
#          </li>
#          <li>
#           3.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-3-IFT" title='Transcript of episode 3 "I.F.T."'>
#            I.F.T.
#           </a>
#          </li>
#          <li>
#           4.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-4-Green_Light" title='Transcript of episode 4 "Green Light"'>
#            Green Light
#           </a>
#          </li>
#          <li>
#           5.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-5-Ms" title='Transcript of episode 5 "Más"'>
#            Más
#           </a>
#          </li>
#          <li>
#           6.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-6-Sunset" title='Transcript of episode 6 "Sunset"'>
#            Sunset
#           </a>
#          </li>
#          <li>
#           7.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-7-One_Minute" title='Transcript of episode 7 "One Minute"'>
#            One Minute
#           </a>
#          </li>
#          <li>
#           8.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-8-I_See_You" title='Transcript of episode 8 "I See You"'>
#            I See You
#           </a>
#          </li>
#          <li>
#           9.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-9-Kafkaesque" title='Transcript of episode 9 "Kafkaesque"'>
#            Kafkaesque
#           </a>
#          </li>
#          <li>
#           10.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-10-Fly" title='Transcript of episode 10 "Fly"'>
#            Fly
#           </a>
#          </li>
#          <li>
#           11.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-11-Abiquiu" title='Transcript of episode 11 "Abiquiu"'>
#            Abiquiu
#           </a>
#          </li>
#          <li>
#           12.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-12-Half_Measures" title='Transcript of episode 12 "Half Measures"'>
#            Half Measures
#           </a>
#          </li>
#          <li>
#           13.
#           <a href="/series/Breaking_Bad-903747/season-3/episode-13-Full_Measure" title='Transcript of episode 13 "Full Measure"'>
#            Full Measure
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="season">
#         <h4>
#          Season 4
#         </h4>
#         <ul>
#          <li>
#           1.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-1-Box_Cutter" title='Transcript of episode 1 "Box Cutter"'>
#            Box Cutter
#           </a>
#          </li>
#          <li>
#           2.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-2-Thirty-Eight_Snub" title='Transcript of episode 2 "Thirty-Eight Snub"'>
#            Thirty-Eight Snub
#           </a>
#          </li>
#          <li>
#           3.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-3-Open_House" title='Transcript of episode 3 "Open House"'>
#            Open House
#           </a>
#          </li>
#          <li>
#           4.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-4-Bullet_Points" title='Transcript of episode 4 "Bullet Points"'>
#            Bullet Points
#           </a>
#          </li>
#          <li>
#           5.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-5-Shotgun" title='Transcript of episode 5 "Shotgun"'>
#            Shotgun
#           </a>
#          </li>
#          <li>
#           6.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-6-Cornered" title='Transcript of episode 6 "Cornered"'>
#            Cornered
#           </a>
#          </li>
#          <li>
#           7.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-7-Problem_Dog" title='Transcript of episode 7 "Problem Dog"'>
#            Problem Dog
#           </a>
#          </li>
#          <li>
#           8.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-8-Hermanos" title='Transcript of episode 8 "Hermanos"'>
#            Hermanos
#           </a>
#          </li>
#          <li>
#           9.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-9-Bug" title='Transcript of episode 9 "Bug"'>
#            Bug
#           </a>
#          </li>
#          <li>
#           10.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-10-Salud" title='Transcript of episode 10 "Salud"'>
#            Salud
#           </a>
#          </li>
#          <li>
#           11.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-11-Crawl_Space" title='Transcript of episode 11 "Crawl Space"'>
#            Crawl Space
#           </a>
#          </li>
#          <li>
#           12.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-12-End_Times" title='Transcript of episode 12 "End Times"'>
#            End Times
#           </a>
#          </li>
#          <li>
#           13.
#           <a href="/series/Breaking_Bad-903747/season-4/episode-13-Face_Off" title='Transcript of episode 13 "Face Off"'>
#            Face Off
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="season">
#         <h4>
#          Season 5
#         </h4>
#         <ul>
#          <li>
#           1.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-1-Live_Free_or_Die" title='Transcript of episode 1 "Live Free or Die"'>
#            Live Free or Die
#           </a>
#          </li>
#          <li>
#           2.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-2-Madrigal" title='Transcript of episode 2 "Madrigal"'>
#            Madrigal
#           </a>
#          </li>
#          <li>
#           3.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-3-Hazard_Pay" title='Transcript of episode 3 "Hazard Pay"'>
#            Hazard Pay
#           </a>
#          </li>
#          <li>
#           4.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-4-Fifty-One" title='Transcript of episode 4 "Fifty-One"'>
#            Fifty-One
#           </a>
#          </li>
#          <li>
#           5.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-5-Dead_Freight" title='Transcript of episode 5 "Dead Freight"'>
#            Dead Freight
#           </a>
#          </li>
#          <li>
#           6.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-6-Buyout" title='Transcript of episode 6 "Buyout"'>
#            Buyout
#           </a>
#          </li>
#          <li>
#           7.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-7-Say_My_Name" title='Transcript of episode 7 "Say My Name"'>
#            Say My Name
#           </a>
#          </li>
#          <li>
#           8.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-8-Gliding_Over_All" title='Transcript of episode 8 "Gliding Over All"'>
#            Gliding Over All
#           </a>
#          </li>
#          <li>
#           9.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-9-Blood_Money" title='Transcript of episode 9 "Blood Money"'>
#            Blood Money
#           </a>
#          </li>
#          <li>
#           10.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-10-Buried" title='Transcript of episode 10 "Buried"'>
#            Buried
#           </a>
#          </li>
#          <li>
#           11.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-11-Confessions" title='Transcript of episode 11 "Confessions"'>
#            Confessions
#           </a>
#          </li>
#          <li>
#           12.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-12-Rabid_Dog" title='Transcript of episode 12 "Rabid Dog"'>
#            Rabid Dog
#           </a>
#          </li>
#          <li>
#           13.
#           <a hajiilee="" href="/series/Breaking_Bad-903747/season-5/episode-13-Tohajiilee" title='Transcript of episode 13 "To'>
#            To'hajiilee
#           </a>
#          </li>
#          <li>
#           14.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-14-Ozymandias" title='Transcript of episode 14 "Ozymandias"'>
#            Ozymandias
#           </a>
#          </li>
#          <li>
#           15.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-15-Granite_State" title='Transcript of episode 15 "Granite State"'>
#            Granite State
#           </a>
#          </li>
#          <li>
#           16.
#           <a href="/series/Breaking_Bad-903747/season-5/episode-16-Felina" title='Transcript of episode 16 "Felina"'>
#            Felina
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#       </script>
#       <!-- subslikescript 336*280 bottom -->
#       <ins class="adsbygoogle" data-ad-client="ca-pub-6250492176235895" data-ad-format="auto" data-ad-slot="1208640000" data-full-width-responsive="true" style="display:block">
#       </ins>
#       <script>
#        (adsbygoogle = window.adsbygoogle || []).push({});
#       </script>
#      </article>
#     </main>
#     <div class="left-side">
#     </div>
#     <div class="right-side">
#     </div>
#    </div>
#    <!--main-wrapper div ending-->
#    <footer>
#     <span class="contactus">
#      Have any questions? Contact us: subslikescript(doggysign)gmail.com |
#      <a href="/dmca">
#       DMCA
#      </a>
#     </span>
#    </footer>
#   </div>
#   <!-- wrapper ends -->
#   <script>
#    (function(){var js = "window['__CF$cv$params']={r:'85895ba14ef12e31',t:'MTcwODQ1OTQ1OS4xMDAwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();
#   </script>
#  </body>
# </html>

# %%
box=soup.find('article', class_='main-article')

# %%
title = box.find('h1').get_text()
print(title)
# Out:
# Breaking Bad (2008–2013) - episodes with scripts

# %%
plot = box.find('p', class_='plot').get_text(strip=True,separator=' ')

# %%
print(plot)
# Out:
# When chemistry teacher Walter White is diagnosed with Stage III cancer and given only two years to live, he decides he has nothing to lose. He lives with his teenage son, who has cerebral palsy, and his wife, in New Mexico. Determined to ensure that his family will have a secure future, Walt embarks on a career of drugs and crime. He proves to be remarkably proficient in this new world as he begins manufacturing and selling methamphetamine with one of his former students. The series tracks the impacts of a fatal diagnosis on a regular, hard working man, and explores how a fatal diagnosis affects his morality and transforms him into a major player of the drug trade.

# %%
with open(f'{title}.txt', 'w') as file:
    file.write(plot)
